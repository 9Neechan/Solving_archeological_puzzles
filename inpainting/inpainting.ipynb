# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

def show(im):
    plt.axis('off')
    plt.imshow(im)

'''
img = cv2.imread('orig.png')
#mask = cv.imread('mask.jpg', cv.IMREAD_GRAYSCALE) cv2.COLOR_RGB2GRAY
mask = cv2.imread('mask.jpg', cv2.COLOR_RGB2GRAY) 
dst = cv2.inpaint(img, mask, 3, cv2.INPAINT_TELEA)
cv2.imshow('dst',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
'''

name_img = "piece"
num = ""

# %%
img = cv2.imread(f'../images/_extrapolated/{name_img}_ext.png')

# %%
mask = cv2.imread(f'../images/_mask/{name_img}_mask.png', 0)

#cv2.imshow('dst',dst)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
dst = cv2.inpaint(img,mask, 3, cv2.INPAINT_TELEA)
cv2.imwrite(f'filled{num}.jpg', dst)

img = cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)
show(img)
